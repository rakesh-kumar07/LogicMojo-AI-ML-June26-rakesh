# %% [markdown]
# <a href="https://colab.research.google.com/github/rakesh-kumar07/LogicMojo-AI-ML-June26-rakesh/blob/main/week1/week_1_logicmojo_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add():
  a=10
  b=20
  print(a+b)
add()
# Out:
# 30

# %%
x=101
print(x)
def mainfun():
  global x
  print(x)
  x='wlecome to python'
  print(x)
mainfun()
print(x+' '+x)
# Out:
# 101
# 101
# wlecome to python
# wlecome to python wlecome to python

# %%
name=input("enter your name")
print("Hello, "+name)
# Out:
# enter your nameRakesh
# Hello, Rakesh

# %%
age=int(input("Enter your age"))
print('your are ',age, ' years old')
# Out:
# Enter your age28
# your are  28  years old

# %%
numbers=input("Enter numbers seperated by space: ").split()
numbers=[int(num) for num in numbers]
print("you entered:", numbers)
# Out:
# Enter numbers seperated by space: 1 2 3 4 5
# you entered: [1, 2, 3, 4, 5]

# %%
a,b=input("enter two number seperated by space: ").split()
a=int(a)
b=int(b)
print("1st num",a)
print("2nd num",b)
# Out:
# enter two number seperated by space: 11 22
# 1st num 11
# 2nd num 22

# %%
a, b=map(int, input("Enter space seperated numbers: ").split())
print("1st num",a)
print("2nd num",b)
# Out:
# Enter space seperated numbers: 31 24
# 1st num 31
# 2nd num 24

# %%
d=int(3)
print(bin(~ d))
# Out:
# -0b100

# %%
a=10.8
print(int(a))
# Out:
# 10
